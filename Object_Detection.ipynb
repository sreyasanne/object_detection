# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Thu Sep 12 17:02:53 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15851, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15851 (delta 5), reused 11 (delta 4), pack-reused 15833 (from 1)
# Receiving objects: 100% (15851/15851), 14.42 MiB | 15.04 MiB/s, done.
# Resolving deltas: 100% (10671/10671), done.

# %%
# !sudo rm /usr/local/cuda/bin/gcc
# !sudo rm /usr/local/cuda/bin/g++
# Out:
# rm: cannot remove '/usr/local/cuda/bin/gcc': No such file or directory
# rm: cannot remove '/usr/local/cuda/bin/g++': No such file or directory

# %%
# !sudo ln -s /usr/bin/gcc-9 /usr/local/cuda/bin/gcc
# !sudo ln -s /usr/bin/g++-9 /usr/local/cuda/bin/g++

# %%
# !ls -l /usr/local/cuda/bin/gcc
# !ls -l /usr/local/cuda/bin/g++
# Out:
# lrwxrwxrwx 1 root root 14 Sep 12 17:03 /usr/local/cuda/bin/gcc -> /usr/bin/gcc-9
# lrwxrwxrwx 1 root root 14 Sep 12 17:03 /usr/local/cuda/bin/g++ -> /usr/bin/g++-9

# %%
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-9 60
# !sudo update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-9 60
# Out:
# update-alternatives: error: alternative path /usr/bin/gcc-9 doesn't exist
# update-alternatives: error: alternative path /usr/bin/g++-9 doesn't exist

# %%
# !gcc --version
# !g++ --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# g++ (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
#       |              ^~~~
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# !chmod a+x ./darknet
# Out:
# --2024-09-12 17:04:57--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  11.6MB/s    in 11s
#
# 2024-09-12 17:05:08 (22.0 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
/pwd
# Out:
# '/content/darknet'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Update package list
# !sudo apt update

# Upgrade installed packages
# !sudo apt upgrade -y

# Upgrade distribution (optional)
# !sudo apt full-upgrade -y

# Remove unnecessary packages (optional)
# !sudo apt autoremove -y

# Check for repository issues
# !cat /etc/apt/sources.list
# !ls /etc/apt/sources.list.d/
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [999 kB]
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,573 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
import cv2

# Load the video
cap = cv2.VideoCapture('/content/test.mp4')

# Check if the video loaded successfully
if not cap.isOpened():
    print("Error opening video file")
else:
    print("Video file loaded successfully")

# Print video properties
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

print(f'Total frames: {frame_count}')
print(f'FPS: {fps}')
print(f'Resolution: {width}x{height}')

cap.release()
# Out:
# Video file loaded successfully
# Total frames: 210
# FPS: 30.0
# Resolution: 1728x1080

# %%
# !ls -l darknet
# !make clean
# !make
# Out:
# -rwxr-xr-x 1 root root 4938192 Sep 12 17:04 darknet
# ...

# %%
# !ls /content/
# Out:
# darknet  drive	gdrive	sample_data  test.mp4

# %%
from IPython.display import Video
Video('/content/test.mp4')
# Out:
# <video src="/content/test.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show -i 0 -out_filename /content/output1.avi -thresh 0.7 /content/test.mp4
# Out:
#  CUDA-version: 12020 (12020), GPU count: 1
#  OpenCV version: 4.5.4
# Demo
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
from google.colab import files
files.download('/content/output1.avi')
